# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
plt.bar(['fMRI decoding'],[0.2])
plt.bar(['matching'],[0.5])
plt.bar(['generative'],[0.6])
plt.bar(['UNET'],[0.4])
plt.ylabel("Similarity")
plt.title("Structural Similarity Index Measure(SSIM)")
# Out:
# Text(0.5, 1.0, 'Structural Similarity Index Measure(SSIM)')

# %%
plt.bar(['fMRI decoding'],[2])
plt.bar(['matching'],[15])
plt.bar(['generative'],[10])
plt.bar(['UNET'],[20])
plt.ylabel("Distance")
plt.title("Frechet Inception Distance (FID)")
# Out:
# Text(0.5, 1.0, 'Frechet Inception Distance (FID)')
