# %%
# percentage correct?
# distance change?
# 200 day by day change?
# decoding improvement over time (familiarity suppression)?
# embeddings, manifold analysis on local population
# check vae and vgg embeddings?
#

# %%
import torch
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
from modeling.models.bethge import BethgeModel
from modeling.train_utils import array_to_dataloader
from scipy.stats import spearmanr
from scripts.visualize_SharedCore import visualize_neuron
from scipy import optimize
import os

# %%
site = 'm2s1'
nb_validation_samples = 1000
nb_training_samples = 49000

batch_size = 2048

train_y = np.load('D:/school/research/CNN_Tang_project/data/Processed_Tang_data/all_sites_data_prepared/New_response_data/trainRsp_'+site+'.npy')
num_neurons = train_y.shape[1]
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

channels = 256
num_layers = 9
input_size = 50
output_size = num_neurons
first_k = 9
later_k = 3
pool_size = 2
factorized = True

num_maps = 1

net = BethgeModel(channels=channels, num_layers=num_layers, input_size=input_size,
                  output_size=output_size, first_k=first_k, later_k=later_k,
                  input_channels=1, pool_size=pool_size, factorized=True,
                  num_maps=num_maps).cuda()

net.to(device)
net.load_state_dict(torch.load(f'D:/school/research/CNN_Tang_project/saved_models/new_learned_models/{site}_9_model_version_0'))
# Out:
# <All keys matched successfully>

# %%
val_x = np.load('../data/Processed_Tang_data/all_sites_data_prepared/pics_data/val_img_' + site + '.npy')
val_x = np.transpose(val_x, (0, 3, 1, 2))
val_y = np.load('../data/Processed_Tang_data/all_sites_data_prepared/New_response_data/valRsp_' + site + '.npy')
num_neurons = val_y.shape[1]
val_loader = array_to_dataloader(val_x, val_y, batch_size=200)
prediction = []
actual = []
for batch_num, (x, y) in enumerate(tqdm(val_loader)):
    x, y = x.to(device), y.to(device)
    outputs = net(x).detach().cpu().numpy()
    prediction.extend(outputs)
    actual.extend(y.detach().cpu().numpy())

prediction = np.stack(prediction)
actual = np.stack(actual)
# Out:
# 100%|██████████| 5/5 [00:01<00:00,  2.69it/s]

# %%
train_x = np.load('../data/Processed_Tang_data/all_sites_data_prepared/pics_data/train_img_' + site + '.npy')
train_x = np.transpose(train_x, (0, 3, 1, 2))
train_y = np.load('../data/Processed_Tang_data/all_sites_data_prepared/New_response_data/trainRsp_' + site + '.npy')
train_loader = array_to_dataloader(train_x, train_y, batch_size=200)
prediction_train = []
actual_train = []
for batch_num, (x, y) in enumerate(tqdm(train_loader)):
    x, y = x.to(device), y.to(device)
    outputs = net(x).detach().cpu().numpy()
    prediction_train.extend(outputs)
    actual_train.extend(y.detach().cpu().numpy())

prediction_train = np.stack(prediction_train)
actual_train = np.stack(actual_train)
# Out:
# 100%|██████████| 245/245 [00:42<00:00,  5.82it/s]

# %%
prediction_all = np.concatenate((prediction,prediction_train),axis=0)
actual_all = np.concatenate((actual,actual_train),axis=0)

# %%
#LLE experiment
from sklearn.manifold import LocallyLinearEmbedding

embedding = LocallyLinearEmbedding(n_components=3, method="standard",n_neighbors=10)
prediction_transformed = embedding.fit_transform(prediction_all[:1000])

# %%
import matplotlib as mpl
# %matplotlib

plt.ion()
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(prediction_transformed[:,0], prediction_transformed[:,1], prediction_transformed[:,2])
plt.show()
#np.save("lle_prediction_all",prediction_transformed)
# Out:
# Using matplotlib backend: module://ipympl.backend_nbagg
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
embedding = LocallyLinearEmbedding(n_components=3, method="standard",n_neighbors=10)
actual_transformed = embedding.fit_transform(actual_all[:1000])
plt.ion()
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(actual_transformed[:,0], actual_transformed[:,1], actual_transformed[:,2])
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
embedding = LocallyLinearEmbedding(n_components=2, method="standard",n_neighbors=10)
actual_transformed = embedding.fit_transform(actual_all[5000:9000])
figr2 = plt.figure()
axr = plt.axes()
axr.scatter(actual_transformed[:,0], actual_transformed[:,1]);

# %%
fig = plt.figure()
ax = Axes3D(fig)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
predictionPCA = pca.fit_transform(prediction_all[:5000])
actualPCA = pca.fit_transform(actual_all[:5000])
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(predictionPCA[:,0], predictionPCA[:,1], predictionPCA[:,2])
figr = plt.figure()
axr = plt.axes(projection='3d')
axr.scatter3D(actualPCA[:,0], actualPCA[:,1], actualPCA[:,2]);

# %%
from sklearn.manifold import TSNE

p_embedded = TSNE(n_components=2, learning_rate='auto',
                   init='random', perplexity=3).fit_transform(prediction_all[:5000])
a_embedded = TSNE(n_components=2, learning_rate='auto',
                   init='random', perplexity=3).fit_transform(actual_all[:5000])

# %%
fig = plt.figure()
ax = plt.axes()
ax.scatter(p_embedded[:,0], p_embedded[:,1])
fig = plt.figure()
ax = plt.axes()
ax.scatter(a_embedded[:,0], a_embedded[:,1])

# %%
rsp_dist = np.zeros((1000,1000))
for real_idx, real in enumerate(actual):
    for pred_idx, pred in enumerate(prediction):
        rsp_dist[real_idx,pred_idx] = (np.square(pred - real)).mean()

# %%
rsp_sorted = np.argsort(rsp_dist,axis = 1)

# %%
np.save('rsp_sorted',rsp_sorted)

# %%
correct_rsp_position = np.zeros(1000)
for i, rsp_list in enumerate(rsp_sorted):
    correct_rsp_position[i] = np.where(rsp_list==i)[0]

# %%
plt.hist(correct_rsp_position)
print(np.median(correct_rsp_position))
# Out:
# 1.0

# %%
rsp_dist = np.zeros((1000, 50000))
for real_idx, real in enumerate(actual):
    for pred_idx, pred in enumerate(prediction_all):
        rsp_dist[real_idx, pred_idx] = (np.square(pred - real)).mean()

rsp_sorted = np.argsort(rsp_dist, axis=1)
correct_rsp_position = np.zeros(1000)
for i, rsp_list in enumerate(rsp_sorted):
    correct_rsp_position[i] = np.where(rsp_list == i)[0]
plt.hist(correct_rsp_position)
print(np.median(correct_rsp_position))
# Out:
# 37.0

# %%
def make_dir_try(dir):
    try:
        os.makedirs(dir, exist_ok=True)
        print("Directory '%s' created successfully" % dir)
    except OSError as error:
        print("Directory '%s' can not be created" % dir)

# %%
directory = f'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/{site}_full'
make_dir_try(directory)
# Out:
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_full' created successfully

# %%
all_x = np.concatenate((val_x,train_x),axis=0)
for i, position in enumerate(correct_rsp_position):
    sample_dir = directory + f'/sample{i}_position{position}'
    make_dir_try(sample_dir)
    top_5_match = rsp_sorted[i, :10]
    top_5_img = all_x[top_5_match]
    for img_idx, img in enumerate(top_5_img):
        img = np.reshape(img, (50,50))
        plt.imsave(sample_dir + f'/ranked{img_idx}_valNum{top_5_match[img_idx]}.png', img, cmap='gray')
# Out:
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_full/s
created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample322' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample323' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample324' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample325' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample326' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample327' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample328' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample329' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample330' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample331' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample332' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample333' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample334' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample335' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample336' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample337' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample338' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample339' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample340' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample341' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample342' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample343' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample344' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample345' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample346' created successfully
# ...
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample357' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample358' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample359' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample360' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample361' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample362' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample363' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample364' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample365' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample366' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample367' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample368' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample369' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample370' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample371' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample372' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample373' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample374' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample375' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample376' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample377' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample378' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample379' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample380' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample381' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample382' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample383' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample384' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample385' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample386' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample387' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample388' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample389' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample390' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample391' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample392' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample393' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample394' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample395' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample396' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample397' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample398' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample399' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample400' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample401' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample402' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample403' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample404' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample405' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample406' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample407' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample408' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample409' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample410' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample411' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample412' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample413' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample414' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample415' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample416' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample417' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample418' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample419' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample420' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample421' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample422' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample423' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample424' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample425' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample426' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample427' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample428' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample429' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample430' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample431' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample432' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample433' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample434' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample435' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample436' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample437' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample438' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample439' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample440' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample441' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample442' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample443' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample444' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample445' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample446' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample447' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample448' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample449' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample450' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample451' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample452' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample453' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample454' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample455' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample456' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample457' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample458' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample459' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample460' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample461' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample462' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample463' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample464' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample465' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample466' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample467' created successfully
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_real_full/sample468' created successfully
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[52], line 7
#       5 make_dir_try(sample_dir)
#       6 top_5_match = rsp_sorted_real[i, :10]
# ----> 7 top_5_img = val_x[top_5_match]
#       8 for img_idx, img in enumerate(top_5_img):
#       9     img = np.reshape(img, (50,50))
#
# IndexError: index 32308 is out of bounds for axis 0 with size 1000

# %%
#metrics
from torchmetrics import StructuralSimilarityIndexMeasure
ssim = StructuralSimilarityIndexMeasure(reduction='none').to(device)
score = torch.zeros((1000,1000))
for i, position in tqdm(enumerate(correct_rsp_position)):
    top_match = rsp_sorted[i,:1000]
    top_img = all_x[top_match]
    correct_img = all_x[int(position)]

    score[i] = (ssim(torch.tensor(top_img).to(device),torch.tensor([correct_img for i in range(1000)]).to(device)))

score = score.detach().cpu().numpy()
# Out:
# 1000it [04:23,  3.79it/s]

# %%
#metrics
top_number = 10
mse_score = np.zeros((1000,10))
for i, position in tqdm(enumerate(correct_rsp_position)):
    top_match = rsp_sorted[i,:top_number]
    top_img = np.reshape(all_x[top_match],(top_number,2500))
    correct_img = np.reshape(all_x[int(position)],2500)
    correct_img_matrix = np.array([correct_img for i in range(top_number)])
    mse_score[i] = (np.square(correct_img_matrix - top_img)).mean(axis=1)
# Out:
# 1000it [00:00, 11237.85it/s]

# %%
#metrics
top_number = 10
corr_score = np.zeros((1000,10))
for i, position in tqdm(enumerate(correct_rsp_position)):
    top_match = rsp_sorted[i,:top_number]
    top_img = np.reshape(all_x[top_match],(top_number,2500))
    correct_img = np.reshape(all_x[int(position)],2500)
    for j, img in enumerate(top_img):
        corr_score[i,j] = np.corrcoef([img, correct_img])[0,1]
# Out:
# 1000it [00:00, 1140.95it/s]

# %%
from torchvision import transforms, models
class Img2VecResnet18():
    def __init__(self):

        self.device = torch.device("cuda")
        self.numberFeatures = 512
        self.modelName = "resnet-18"
        self.model, self.featureLayer = self.getFeatureLayer()
        self.model = self.model.to(self.device)
        self.model.eval()
        self.toTensor = transforms.ToTensor()

        # normalize the resized images as expected by resnet18
        # [0.485, 0.456, 0.406] --> normalized mean value of ImageNet, [0.229, 0.224, 0.225] std of ImageNet
        self.normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])

    def getVec(self, img):
        image = self.normalize(self.toTensor(img)).unsqueeze(0).to(self.device)
        embedding = torch.zeros(1, self.numberFeatures, 1, 1)

        def copyData(m, i, o): embedding.copy_(o.data)

        h = self.featureLayer.register_forward_hook(copyData)
        self.model(image)
        h.remove()

        return embedding.numpy()[0, :, 0, 0]

    def getFeatureLayer(self):

        cnnModel = models.resnet18(pretrained=True)
        layer = cnnModel._modules.get('avgpool')
        self.layer_output_size = 512

        return cnnModel, layer


# generate vectors for all the images in the set
img2vec = Img2VecResnet18()


score = torch.zeros((1000,1000))
for i, position in tqdm(enumerate(correct_rsp_position)):
    top_match = rsp_sorted[i,:1000]
    top_img = all_x[top_match][0]
    correct_img = all_x[int(position)]
    for img in top_img:
        img_embedding = img2vec.getVec(img)
        print(x)
# Out:
# 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[45], line 48
#      46 correct_img = all_x[int(position)]
#      47 for img in top_img:
# ---> 48     img_embedding = img2vec.getVec(img)
#      49     print(x)
#
# Cell In[45], line 18, in Img2VecResnet18.getVec(self, img)
#      17 def getVec(self, img):
# ---> 18     image = self.normalize(self.toTensor(img)).unsqueeze(0).to(self.device)
#      19     embedding = torch.zeros(1, self.numberFeatures, 1, 1)
#      21     def copyData(m, i, o): embedding.copy_(o.data)
#
# File ~\.conda\envs\torch\lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~\.conda\envs\torch\lib\site-packages\torchvision\transforms\transforms.py:277, in Normalize.forward(self, tensor)
#     269 def forward(self, tensor: Tensor) -> Tensor:
#     270     """
#     271     Args:
#     272         tensor (Tensor): Tensor image to be normalized.
#    (...)
#     275         Tensor: Normalized Tensor image.
#     276     """
# --> 277     return F.normalize(tensor, self.mean, self.std, self.inplace)
#
# File ~\.conda\envs\torch\lib\site-packages\torchvision\transforms\functional.py:363, in normalize(tensor, mean, std, inplace)
#     360 if not isinstance(tensor, torch.Tensor):
#     361     raise TypeError(f"img should be Tensor Image. Got {type(tensor)}")
# --> 363 return F_t.normalize(tensor, mean=mean, std=std, inplace=inplace)
#
# File ~\.conda\envs\torch\lib\site-packages\torchvision\transforms\_functional_tensor.py:928, in normalize(tensor, mean, std, inplace)
#     926 if std.ndim == 1:
#     927     std = std.view(-1, 1, 1)
# --> 928 return tensor.sub_(mean).div_(std)
#
# RuntimeError: output with shape [1, 50, 50] doesn't match the broadcast shape [3, 50, 50]

# %%
directory = f'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/{site}_SSIM'
make_dir_try(directory)
for i, s in enumerate(score):
    plt.figure()
    plt.plot(s[:10])
    plt.savefig(directory+f'/SSIM_image_{i}')
    plt.close()
# Out:
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_SSIM' created successfully

# %%
directory = f'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/{site}_MSE'
make_dir_try(directory)
for i, s in enumerate(mse_score):
    plt.figure()
    _ = plt.plot(s)
    plt.savefig(directory+f'/SSIM_image_{i}')

# %%
directory = f'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/{site}_corr'
make_dir_try(directory)
for i, s in enumerate(corr_score):
    plt.figure()
    plt.plot(s)
    plt.savefig(directory+f'/corr_image_{i}')
    plt.close()
# Out:
# Directory 'D:/school/research/CNN_Tang_project/analysis/Reconstruction/match_recon_results/m2s1_corr' created successfully
